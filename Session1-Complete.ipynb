# %% [markdown]
# # Open recordings and verify quality and coverage

# %%
import sys
import os
import time
import datetime as dt
import math
import numpy as np 
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json 
import heartpy as hp

from scipy.signal import butter, filtfilt, argrelextrema
from scipy import interpolate
from scipy.interpolate import interp1d

# %%
# %load_ext autoreload
# %autoreload 1
# %aimport qex
# %aimport rp2
# %aimport mh

# %%
 # %reload_ext autoreload

# %%
def rmssd(ibi_list):
    ibi_list = pd.Series(ibi_list)
    ms = np.sqrt(ibi_list.diff().pow(2).sum()/(len(ibi_list)-1))
    return ms

def HR_avg(ibi_list):
    ibi_list = pd.Series(ibi_list)
    bpm = 60000/ibi_list.mean()
    return bpm


def get_spectrogram(datain,F,W,J,scale='log'):
    '''Makes a spectrogram of the given data.
    #
    df: dataframe with data
    F: sampling frequency
    W: Window size
    J: Separation between windows
    #
    output: if input is Series output is a signle DF with spectrogram
            if intput is DF the output is dictionary with one spectrogram per column of the input dataframe
    '''
    K = range(0,len(datain)-W,J) # starting point for the windows
    K0 = [int(x+W/2) for x in K] # placing them in the middle point timestamp
    new_index = [datain.index[x] for x in K0] # extracting those timestamps
    col_freqs = [x*F/W for x in range(int(W/2)+1) ] # values of resolved freqs
    #   print(len(new_index),len(col_freqs))
    han = np.hanning(W)
    #dic = {'window_size':W,'sampling_frequency':F}
    #
    dic = {}
    for col in datain.columns:
        fourier = np.zeros((len(new_index),len(col_freqs)))
        temp = np.zeros((1,int(W/2)+1))
        j = 0
        D = datain[col]
#         D = D.diff() # discrete derivative
        D = D.dropna() # discarding nans and concatenating
        if len(D)==0:
            continue
        #   
        K0 = range(0,len(D)-W,J) # starting point for the windows
        for T0 in K0:
            data0 = D.iloc[T0:T0+W]*han
            if scale=='log':
                temp = 10*np.log10(2*abs(np.fft.fft(data0,axis=0)))
            elif scale=='abs':
                temp = abs(np.fft.fft(data0,axis=0))
            fourier[j,:] = temp[:int(W/2)+1]
            j = 1 + j
            #
        res = pd.DataFrame(fourier,index=new_index,columns=col_freqs)
#         res1 = res / (res.columns) # multiplicative adjustment for discrete derivative
        dic[col] = res#1      
        #print('Ready with ',col)
    output = dic
    #
    return output

# %% [markdown]
# ## load example data

# %%
mydpi = 196
sess_tag = '0524'

# %%
Timing_file = pd.read_csv('../Timing/Onset times, session 1.1-1.csv',skiprows=5)
Timing_file
# Out:
#        Times  HR  RMSSD  Resp.  Movem.  Unnamed: 5   Times.1  HR.1  RMSSD.1  \
# 0   08:32:44 NaN    NaN    NaN     NaN         NaN  08:32:44   NaN      NaN
# 1   08:35:42 NaN    NaN    NaN     NaN         NaN  08:35:42   NaN      NaN
# 2   08:39:47 NaN    NaN    NaN     NaN         NaN  08:39:47   NaN      NaN
# 3   08:41:22 NaN    NaN    NaN     NaN         NaN  08:41:22   NaN      NaN
# 4   08:45:02 NaN    NaN    NaN     NaN         NaN  08:45:02   NaN      NaN
# 5   08:48:02 NaN    NaN    NaN     NaN         NaN  08:48:02   NaN      NaN
# 6   08:52:18 NaN    NaN    NaN     NaN         NaN  08:52:18   NaN      NaN
# 7   08:54:19 NaN    NaN    NaN     NaN         NaN  08:54:19   NaN      NaN
# 8   08:55:32 NaN    NaN    NaN     NaN         NaN  08:55:32   NaN      NaN
# 9   08:58:12 NaN    NaN    NaN     NaN         NaN  08:58:12   NaN      NaN
# 10  09:01:33 NaN    NaN    NaN     NaN         NaN  09:01:33   NaN      NaN
# 11  09:04:52 NaN    NaN    NaN     NaN         NaN  09:04:52   NaN      NaN
# 12  09:07:27 NaN    NaN    NaN     NaN         NaN  09:07:27   NaN      NaN
# 13  09:12:10 NaN    NaN    NaN     NaN         NaN  09:12:10   NaN      NaN
# 14  09:17:02 NaN    NaN    NaN     NaN         NaN  09:17:02   NaN      NaN
# 15  09:20:22 NaN    NaN    NaN     NaN         NaN  09:20:22   NaN      NaN
# 16  09:24:47 NaN    NaN    NaN     NaN         NaN  09:24:47   NaN      NaN
# 17  09:28:04 NaN    NaN    NaN     NaN         NaN  09:28:04   NaN      NaN
# 18       NaN NaN    NaN    NaN     NaN         NaN       NaN   NaN      NaN
# 19       NaN NaN    NaN    NaN     NaN         NaN       NaN   NaN      NaN
# 20       NaN NaN    NaN    NaN     NaN         NaN       NaN   NaN      NaN
# 21       NaN NaN    NaN    NaN     NaN         NaN       NaN   NaN      NaN
# 22       NaN NaN    NaN    NaN     NaN         NaN       NaN   NaN      NaN
# 23       NaN NaN    NaN    NaN     NaN         NaN       NaN   NaN      NaN
#
#     Resp..1  Movem..1
# 0       NaN       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN
# 5       NaN       NaN
# 6       NaN       NaN
# 7       NaN       NaN
# 8       NaN       NaN
# 9       NaN       NaN
# 10      NaN       NaN
# 11      NaN       NaN
# 12      NaN       NaN
# 13      NaN       NaN
# 14      NaN       NaN
# 15      NaN       NaN
# 16      NaN       NaN
# 17      NaN       NaN
# 18      NaN       NaN
# 19      NaN       NaN
# 20      NaN       NaN
# 21      NaN       NaN
# 22      NaN       NaN
# 23      NaN       NaN

# %%
Excerpt_times = pd.to_datetime('May 24th, 2023, ' + Timing_file.loc[:17,'Times'])
Excerpt_times
# Out:
# 0    2023-05-24 08:32:44
# 1    2023-05-24 08:35:42
# 2    2023-05-24 08:39:47
# 3    2023-05-24 08:41:22
# 4    2023-05-24 08:45:02
# 5    2023-05-24 08:48:02
# 6    2023-05-24 08:52:18
# 7    2023-05-24 08:54:19
# 8    2023-05-24 08:55:32
# 9    2023-05-24 08:58:12
# 10   2023-05-24 09:01:33
# 11   2023-05-24 09:04:52
# 12   2023-05-24 09:07:27
# 13   2023-05-24 09:12:10
# 14   2023-05-24 09:17:02
# 15   2023-05-24 09:20:22
# 16   2023-05-24 09:24:47
# 17   2023-05-24 09:28:04
# Name: Times, dtype: datetime64[ns]

# %%
Excerpt_times.iloc[[0,-1]]
# Out:
# 0    2023-05-24 08:32:44
# 17   2023-05-24 09:28:04
# Name: Times, dtype: datetime64[ns]

# %%
data_loc = '../Equivitals_Sessions1/'
eqfiles = qex.qiosk_rec_check(data_loc,'','/')
eqfiles = qex.remove_tz_from_dataframe(eqfiles)
eqfiles
# Out:
#   Signal      DevName       ID    Date  Session  \
# 0   DATA  BLUETOOTH01  5022281  230524        0
# 1   DATA  BLUETOOTH03  5022292  230524        0
# 2   DATA  BLUETOOTH01  5022281  230607      101
# 3   DATA  BLUETOOTH02  5022285  230607      101
# 4   DATA  BLUETOOTH02  5022285  230614        0
# 5   DATA  BLUETOOTH01  5022281  230614      101
# 6   DATA  BLUETOOTH02  5022285  230621      101
# 7   DATA  BLUETOOTH01  5022281  230621        0
#
#                                   FileName FileType  FileSize  \
# 0    DATA-BLUETOOTH01-5022281-23052400.CSV      csv     28098
# 1    DATA-BLUETOOTH03-5022292-23052400.CSV      csv     28550
# 2  DATA-BLUETOOTH01-5022281-23060700_0.CSV      csv     31895
# 3  DATA-BLUETOOTH02-5022285-23060700_0.CSV      csv     31987
# 4    DATA-BLUETOOTH02-5022285-23061400.CSV      csv     25872
# 5  DATA-BLUETOOTH01-5022281-23061400_0.CSV      csv     25181
# 6  DATA-BLUETOOTH02-5022285-23062100_0.CSV      csv     25737
# 7    DATA-BLUETOOTH01-5022281-23062100.CSV      csv     25336
#
#              RecStart              RecEnd  ...   SubjectNames  SENSOR ID  \
# 0 2023-05-24 08:16:08 2023-05-24 09:34:23  ...  [BLUETOOTH01]  5022281.0
# 1 2023-05-24 08:16:56 2023-05-24 09:36:26  ...  [BLUETOOTH03]  5022292.0
# 2 2023-06-07 08:12:51 2023-06-07 09:41:36  ...  [BLUETOOTH01]  5022281.0
# 3 2023-06-07 08:13:29 2023-06-07 09:42:29  ...  [BLUETOOTH02]  5022285.0
# 4 2023-06-14 07:22:35 2023-06-14 08:34:35  ...  [BLUETOOTH02]  5022285.0
# 5 2023-06-14 07:23:47 2023-06-14 08:33:32  ...  [BLUETOOTH01]  5022281.0
# 6 2023-06-21 08:21:54 2023-06-21 09:33:24  ...  [BLUETOOTH02]  5022285.0
# 7 2023-06-21 08:22:30 2023-06-21 09:32:45  ...  [BLUETOOTH01]  5022281.0
#
#     SUBJECT ID  SUBJECT AGE HR(BPM) HRC(%) BELT OFF LEAD OFF      MOTION  \
# 0  BLUETOOTH01          NaN      62   99.0      0.0      0.0  Stationary
# 1  BLUETOOTH03          NaN      80   98.0      0.0      0.0  Stationary
# 2  BLUETOOTH01          NaN      61   99.0      0.0      0.0  Stationary
# 3  BLUETOOTH02          NaN      80   97.0      0.0      0.0  Stationary
# 4  BLUETOOTH02          NaN      77   98.0      0.0      0.0  Stationary
# 5  BLUETOOTH01          NaN      61  100.0      0.0      0.0  Stationary
# 6  BLUETOOTH02          NaN      86   98.0      0.0      0.0  Stationary
# 7  BLUETOOTH01          NaN      60  100.0      0.0      0.0  Stationary
#
#   BODY POSITION
# 0       Upright
# 1       Upright
# 2       Upright
# 3       Upright
# 4       Upright
# 5       Upright
# 6       Upright
# 7       Upright
#
# [8 rows x 30 columns]

# %%
eqfiles
# Out:
#   Signal      DevName       ID    Date  Session  \
# 0   DATA  BLUETOOTH01  5022281  230524        0
# 1   DATA  BLUETOOTH03  5022292  230524        0
# 2   DATA  BLUETOOTH01  5022281  230607      101
# 3   DATA  BLUETOOTH02  5022285  230607      101
# 4   DATA  BLUETOOTH02  5022285  230614        0
# 5   DATA  BLUETOOTH01  5022281  230614      101
# 6   DATA  BLUETOOTH02  5022285  230621      101
# 7   DATA  BLUETOOTH01  5022281  230621        0
#
#                                   FileName FileType  FileSize  \
# 0    DATA-BLUETOOTH01-5022281-23052400.CSV      csv     28098
# 1    DATA-BLUETOOTH03-5022292-23052400.CSV      csv     28550
# 2  DATA-BLUETOOTH01-5022281-23060700_0.CSV      csv     31895
# 3  DATA-BLUETOOTH02-5022285-23060700_0.CSV      csv     31987
# 4    DATA-BLUETOOTH02-5022285-23061400.CSV      csv     25872
# 5  DATA-BLUETOOTH01-5022281-23061400_0.CSV      csv     25181
# 6  DATA-BLUETOOTH02-5022285-23062100_0.CSV      csv     25737
# 7    DATA-BLUETOOTH01-5022281-23062100.CSV      csv     25336
#
#              RecStart              RecEnd  ...   SubjectNames  SENSOR ID  \
# 0 2023-05-24 08:16:08 2023-05-24 09:34:23  ...  [BLUETOOTH01]  5022281.0
# 1 2023-05-24 08:16:56 2023-05-24 09:36:26  ...  [BLUETOOTH03]  5022292.0
# 2 2023-06-07 08:12:51 2023-06-07 09:41:36  ...  [BLUETOOTH01]  5022281.0
# 3 2023-06-07 08:13:29 2023-06-07 09:42:29  ...  [BLUETOOTH02]  5022285.0
# 4 2023-06-14 07:22:35 2023-06-14 08:34:35  ...  [BLUETOOTH02]  5022285.0
# 5 2023-06-14 07:23:47 2023-06-14 08:33:32  ...  [BLUETOOTH01]  5022281.0
# 6 2023-06-21 08:21:54 2023-06-21 09:33:24  ...  [BLUETOOTH02]  5022285.0
# 7 2023-06-21 08:22:30 2023-06-21 09:32:45  ...  [BLUETOOTH01]  5022281.0
#
#     SUBJECT ID  SUBJECT AGE HR(BPM) HRC(%) BELT OFF LEAD OFF      MOTION  \
# 0  BLUETOOTH01          NaN      62   99.0      0.0      0.0  Stationary
# 1  BLUETOOTH03          NaN      80   98.0      0.0      0.0  Stationary
# 2  BLUETOOTH01          NaN      61   99.0      0.0      0.0  Stationary
# 3  BLUETOOTH02          NaN      80   97.0      0.0      0.0  Stationary
# 4  BLUETOOTH02          NaN      77   98.0      0.0      0.0  Stationary
# 5  BLUETOOTH01          NaN      61  100.0      0.0      0.0  Stationary
# 6  BLUETOOTH02          NaN      86   98.0      0.0      0.0  Stationary
# 7  BLUETOOTH01          NaN      60  100.0      0.0      0.0  Stationary
#
#   BODY POSITION
# 0       Upright
# 1       Upright
# 2       Upright
# 3       Upright
# 4       Upright
# 5       Upright
# 6       Upright
# 7       Upright
#
# [8 rows x 30 columns]

# %% [markdown]
# It seems we don't have the correct physiologial measurement files, dating 23 oct and 24 april, not May (24) and June 2023 (7, 14, 21, 28).
#
#
# Below I've constructed the evaluation process, which should be easily ammended to evaluate the correct files.

# %%
sig_tags = ['RESPloc', 'RRloc'] # 'ACCloc', 'DATAloc', , 'ECGloc'
recindex = 0
for sig_file in sig_tags:
    V=pd.read_csv(eqfiles.loc[recindex,sig_file])
    qex.test_plot_signals(V)

# %%
# Session 4,5, 2024-04-02 11:54:11+00:00, aligned at 12:10? 
#timing_adjustment = eqfiles.loc[recindex,'RecStart'] - Timing_file.loc[0,'Times'] + pd.to_timedelta(600,unit='s')
# timing_adjustment = - pd.to_timedelta(3600,unit='s')

# %%
sig_tags = ['RESPloc', 'RRloc'] # 'ACCloc', 'DATAloc', , 'ECGloc'
recindex = 0

t1 = Excerpt_times[0]# + timing_adjustment 
t2 =  Excerpt_times[0]+ pd.to_timedelta(60,unit='s') #+ timing_adjustment 
print([t1,t2])
for sig_file in sig_tags:
    V=pd.read_csv(eqfiles.loc[recindex,sig_file])
    V['DateTime'] = pd.to_datetime(V['DateTime'])
    print(V.loc[0,'DateTime'])
    V = qex.remove_tz_from_dataframe(V)
    qex.test_plot_signals_interval(V,t1,t2)
# Out:
# [Timestamp('2023-05-24 08:32:44'), Timestamp('2023-05-24 08:33:44')]
# 2023-05-24 08:15:40.039000+00:00
# 2023-05-24 08:15:44.843000+00:00

# %% [markdown]
# ### cardiac cleaning

# %%
Evs = []

# %%
recindex = 0

# %%
recindex = 1

# %%
sess_tag = 'Sess0545'
dev_tag = eqfiles.loc[recindex,'DevName']

V = pd.read_csv(eqfiles.loc[recindex,'RRloc']) 
V['DateTime'] = pd.to_datetime(V['DateTime'])
V = qex.remove_tz_from_dataframe(V)
V['c_sTime'] = (V['DateTime']-eqfiles.loc[recindex,'RecStart']).dt.total_seconds()
sig_t = V['c_sTime']
sig_v = V[' Interbeat Interval (MS)']

C = pd.read_csv(eqfiles.loc[recindex,'ECGloc'])
C['DateTime'] = pd.to_datetime(C['DateTime'])
C = qex.remove_tz_from_dataframe(C)
C['c_sTime'] = (C['DateTime']-eqfiles.loc[recindex,'RecStart']).dt.total_seconds()
R = pd.read_csv(eqfiles.loc[recindex,'RESPloc'])
R['DateTime'] = pd.to_datetime(R['DateTime'])
R = qex.remove_tz_from_dataframe(R)
R['c_sTime'] = (R['DateTime']-eqfiles.loc[recindex,'RecStart']).dt.total_seconds()

atype='default'
IBI=mh.clean_IBI(sig_t,sig_v,activitytype=atype)
newIBI = mh.contact_noise_cut(C['c_sTime'],C[' Lead 1'],V['c_sTime'],V[' Interbeat Interval (MS)'],0.25)
newV = V.loc[newIBI.index,:]
newIBI = mh.contact_noise_cut(C['c_sTime'],C[' Lead 2'],newV['c_sTime'],newV[' Interbeat Interval (MS)'],0.25)
newV = newV.loc[newIBI.index,:]
newIBI=mh.clean_IBI(newV['c_sTime'],newV[' Interbeat Interval (MS)'],activitytype=atype)

Respwave = R.query('c_sTime>200').copy()
Respwave.set_index('c_sTime',drop=True,inplace=True)
Breaths = rp2.breath_cycles(rp2.EQ_Inspiration_Extract(Respwave.loc[:,' Breathing']),Respwave.loc[:,' Breathing'])

A = pd.read_csv(eqfiles.loc[recindex,'ACCloc'])
A['DateTime'] = pd.to_datetime(A['DateTime'])
A = qex.remove_tz_from_dataframe(A)
A['c_sTime'] = (A['DateTime']-eqfiles.loc[recindex,'RecStart']).dt.total_seconds()
A['QoM'] = np.sqrt(np.square(A.loc[:,[' Vert Accelerometer', ' Lat Accelerometer',' Long Accelerometer']].diff()).sum(axis=1))
acc_cols = [' Vert Accelerometer', ' Lat Accelerometer',' Long Accelerometer','QoM']
sf = 256
spec= get_spectrogram(A[acc_cols],sf,2048,256,scale='log')
Hz=np.array(spec['QoM'].loc[:,:6].columns)
BPM = np.round(Hz*60,2)


D = pd.read_csv(eqfiles.loc[recindex,'DATAloc'])
D['DateTime'] = pd.to_datetime(D['DateTime'])
D = qex.remove_tz_from_dataframe(D)
D['c_sTime'] = (D['DateTime']-eqfiles.loc[recindex,'RecStart']).dt.total_seconds()

D['HR(BPM)']

Exticks = (Excerpt_times-eqfiles.loc[recindex,'RecStart']).dt.total_seconds()
xrange = [A['c_sTime'].min(),A['c_sTime'].max()]

tstart = Excerpt_times.iloc[0].round('min')-pd.to_timedelta(60,'s')
samples = int(np.floor((Excerpt_times.iloc[-1]-tstart).total_seconds()/60))+1
print(samples)

t_int =60
sig_ex = sess_tag + ' '+ dev_tag
session_stats = {}
for i in range(samples): #17
    t = tstart+i*pd.to_timedelta(60,'s')
    # needs to be corrected when the files have the right correspondence    
    cht = (t-eqfiles.loc[recindex,'RecStart']).total_seconds()
    chx = cht+t_int
    
    interval_stats = {}
    interval_stats['Device'] = dev_tag
    interval_stats['Start Time'] = t.strftime('%Y/%m/%d %H:%M:%S')
    interval_stats['Recording'] = recindex
    
    Ex = C.query('c_sTime>@cht and c_sTime<@chx').copy()
    Ex = V.query('c_sTime>@cht and c_sTime<@chx').copy()
    interval_stats['Initial Beat Count'] = len(Ex)

    Ex = newIBI.query('time>@cht and time<@chx').copy()
    interval_stats['Cleaned Beat Count'] =Ex['IBI'].notna().sum()
    interval_stats['PC Removed'] = 100*np.round((interval_stats['Initial Beat Count'] - interval_stats['Cleaned Beat Count'])/interval_stats['Initial Beat Count'],3)
    interval_stats['Avg HR'] = HR_avg(Ex['IBI'])
    interval_stats['RMSSD'] =rmssd(Ex['IBI'])
    Ex = D.query('c_sTime>@cht and c_sTime<@chx').copy()
    interval_stats['Avg eqHR'] = Ex['HR(BPM)'].mean()
    interval_stats['Mode Motion'] = Ex['MOTION'].mode()[0]
    interval_stats['Mode Posture'] = Ex['BODY POSITION'].mode()[0]

    Ex = R.query('c_sTime>@cht and c_sTime<@chx').copy()
    Ex = Breaths.query('In>@cht and Ex<@chx').copy()
    interval_stats['Breath Count'] = len(Ex)
    interval_stats['Avg BR'] =(60/Ex['Period_T']).mean()
    interval_stats['Avg IE ratio'] =(Ex['IE_Ratio']).mean()
    interval_stats['Seq Var'] =np.power(10,np.log10((Ex['Period_T']/Ex['Period_T'].shift(-1))).abs().mean())


    Ex = A.query('c_sTime>@cht and c_sTime<@chx').copy()
    interval_stats['Avg QoM'] =Ex['QoM'].mean()
    print(interval_stats)
    session_stats[t.strftime('%Y/%m/%d %H:%M:%S')] = interval_stats
Evaluated_Intervals =pd.DataFrame(data=session_stats).transpose()
Evaluated_Intervals.to_csv('_'.join(['./MinuteFiles/'+sess_tag,dev_tag,'minutestats.csv']))
# Out:
# Clipped!
# 57
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:32:00', 'Recording': 1, 'Initial Beat Count': 78, 'Cleaned Beat Count': 78, 'PC Removed': 0.0, 'Avg HR': 78.7998181542658, 'RMSSD': 35.25012664617574, 'Avg eqHR': 79.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 9, 'Avg BR': 11.287992382661477, 'Avg IE ratio': 0.3912001178495901, 'Seq Var': 1.515755706113264, 'Avg QoM': 11.090932875451958}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:33:00', 'Recording': 1, 'Initial Beat Count': 82, 'Cleaned Beat Count': 82, 'PC Removed': 0.0, 'Avg HR': 81.3075308621573, 'RMSSD': 29.5722592731519, 'Avg eqHR': 81.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 11, 'Avg BR': 13.157668371687826, 'Avg IE ratio': 0.3455846188217123, 'Seq Var': 1.3100896934022157, 'Avg QoM': 10.919132939611389}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:34:00', 'Recording': 1, 'Initial Beat Count': 82, 'Cleaned Beat Count': 82, 'PC Removed': 0.0, 'Avg HR': 82.67379139990926, 'RMSSD': 23.929165014091172, 'Avg eqHR': 82.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 12, 'Avg BR': 13.753729872252142, 'Avg IE ratio': 0.3131932580892178, 'Seq Var': 1.4553395666436162, 'Avg QoM': 11.030560436367685}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:35:00', 'Recording': 1, 'Initial Beat Count': 89, 'Cleaned Beat Count': 89, 'PC Removed': 0.0, 'Avg HR': 88.90960856462597, 'RMSSD': 19.990622801703804, 'Avg eqHR': 89.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 15, 'Avg BR': 16.840096334101165, 'Avg IE ratio': 0.49404370249749074, 'Seq Var': 1.6618131199262924, 'Avg QoM': 12.489523625466996}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:36:00', 'Recording': 1, 'Initial Beat Count': 83, 'Cleaned Beat Count': 82, 'PC Removed': 1.2, 'Avg HR': 82.83246628617607, 'RMSSD': 27.385459912773904, 'Avg eqHR': 83.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 14, 'Avg BR': 21.34489157349632, 'Avg IE ratio': 0.408876923116213, 'Seq Var': 2.1088396474975757, 'Avg QoM': 12.287220520234234}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:37:00', 'Recording': 1, 'Initial Beat Count': 84, 'Cleaned Beat Count': 83, 'PC Removed': 1.2, 'Avg HR': 84.77894485963807, 'RMSSD': 31.053393582860604, 'Avg eqHR': 83.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Prone', 'Breath Count': 18, 'Avg BR': 22.06624718625541, 'Avg IE ratio': 0.5031513153353976, 'Seq Var': 1.5206034952047374, 'Avg QoM': 13.168609544772524}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:38:00', 'Recording': 1, 'Initial Beat Count': 90, 'Cleaned Beat Count': 90, 'PC Removed': 0.0, 'Avg HR': 90.04051823320493, 'RMSSD': 19.89099508303339, 'Avg eqHR': 89.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 19, 'Avg BR': 21.340724160446285, 'Avg IE ratio': 0.40790658957424586, 'Seq Var': 1.587722371735626, 'Avg QoM': 11.944233063322432}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:39:00', 'Recording': 1, 'Initial Beat Count': 85, 'Cleaned Beat Count': 85, 'PC Removed': 0.0, 'Avg HR': 84.45945945945947, 'RMSSD': 24.899321084643862, 'Avg eqHR': 85.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 17, 'Avg BR': 18.57733313570626, 'Avg IE ratio': 0.334170475288118, 'Seq Var': 1.2726754799815427, 'Avg QoM': 11.837769095964878}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:40:00', 'Recording': 1, 'Initial Beat Count': 88, 'Cleaned Beat Count': 88, 'PC Removed': 0.0, 'Avg HR': 88.67243261398943, 'RMSSD': 23.799207945866073, 'Avg eqHR': 87.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 17, 'Avg BR': 18.685505100114263, 'Avg IE ratio': 0.3675278875648635, 'Seq Var': 1.4293391338597805, 'Avg QoM': 11.936548450732259}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:41:00', 'Recording': 1, 'Initial Beat Count': 85, 'Cleaned Beat Count': 85, 'PC Removed': 0.0, 'Avg HR': 84.84162895927601, 'RMSSD': 20.91906171072553, 'Avg eqHR': 85.75, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 17, 'Avg BR': 19.773492913374323, 'Avg IE ratio': 0.32734417728830195, 'Seq Var': 1.4665373504377688, 'Avg QoM': 11.85126325333013}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:42:00', 'Recording': 1, 'Initial Beat Count': 80, 'Cleaned Beat Count': 80, 'PC Removed': 0.0, 'Avg HR': 80.41547997989613, 'RMSSD': 25.431466604796626, 'Avg eqHR': 81.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 11, 'Avg BR': 18.673328493638486, 'Avg IE ratio': 0.34508760572653796, 'Seq Var': 2.4995424357383444, 'Avg QoM': 11.612965483576435}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:43:00', 'Recording': 1, 'Initial Beat Count': 87, 'Cleaned Beat Count': 87, 'PC Removed': 0.0, 'Avg HR': 86.68360484232551, 'RMSSD': 20.4191542544033, 'Avg eqHR': 85.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 13, 'Avg BR': 23.42084246207869, 'Avg IE ratio': 0.6183835451083355, 'Seq Var': 2.466003547512193, 'Avg QoM': 11.56310500019776}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:44:00', 'Recording': 1, 'Initial Beat Count': 83, 'Cleaned Beat Count': 83, 'PC Removed': 0.0, 'Avg HR': 82.93365307753797, 'RMSSD': 22.6981787170947, 'Avg eqHR': 85.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 14, 'Avg BR': 13.346686665484043, 'Avg IE ratio': 0.2702411974977727, 'Seq Var': 1.1057194528763195, 'Avg QoM': 11.120692511119376}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:45:00', 'Recording': 1, 'Initial Beat Count': 82, 'Cleaned Beat Count': 82, 'PC Removed': 0.0, 'Avg HR': 82.13552361396304, 'RMSSD': 23.94309096458249, 'Avg eqHR': 81.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 14, 'Avg BR': 16.006803409341888, 'Avg IE ratio': 0.29907327533443645, 'Seq Var': 1.2319626475571914, 'Avg QoM': 11.183586696365662}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:46:00', 'Recording': 1, 'Initial Beat Count': 83, 'Cleaned Beat Count': 83, 'PC Removed': 0.0, 'Avg HR': 82.58158662775271, 'RMSSD': 23.885397110409347, 'Avg eqHR': 82.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 12, 'Avg BR': 13.512859451121841, 'Avg IE ratio': 0.2834189098343827, 'Seq Var': 1.3114419553344119, 'Avg QoM': 11.402647121961241}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:47:00', 'Recording': 1, 'Initial Beat Count': 82, 'Cleaned Beat Count': 82, 'PC Removed': 0.0, 'Avg HR': 82.22474764355906, 'RMSSD': 19.57196281406292, 'Avg eqHR': 82.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 14, 'Avg BR': 17.876682964087056, 'Avg IE ratio': 0.3568647377692997, 'Seq Var': 1.5075207016468155, 'Avg QoM': 12.073770036600724}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:48:00', 'Recording': 1, 'Initial Beat Count': 80, 'Cleaned Beat Count': 80, 'PC Removed': 0.0, 'Avg HR': 80.50314465408805, 'RMSSD': 16.54950379767826, 'Avg eqHR': 81.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 16, 'Avg BR': 22.303938648492995, 'Avg IE ratio': 0.3253599908704833, 'Seq Var': 2.0981091957487172, 'Avg QoM': 11.684972837779162}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:49:00', 'Recording': 1, 'Initial Beat Count': 77, 'Cleaned Beat Count': 77, 'PC Removed': 0.0, 'Avg HR': 76.64360722639725, 'RMSSD': 24.698178070456937, 'Avg eqHR': 76.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 18, 'Avg BR': 23.781544915893647, 'Avg IE ratio': 0.30130872042875817, 'Seq Var': 1.5809551885861028, 'Avg QoM': 11.940819285023434}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:50:00', 'Recording': 1, 'Initial Beat Count': 78, 'Cleaned Beat Count': 78, 'PC Removed': 0.0, 'Avg HR': 78.70837537840565, 'RMSSD': 18.542334853469285, 'Avg eqHR': 79.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 10, 'Avg BR': 12.323391703952579, 'Avg IE ratio': 0.16694408975909664, 'Seq Var': 1.9715804446338718, 'Avg QoM': 11.60670534579904}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:51:00', 'Recording': 1, 'Initial Beat Count': 83, 'Cleaned Beat Count': 83, 'PC Removed': 0.0, 'Avg HR': 82.32765746404364, 'RMSSD': 19.066315591741954, 'Avg eqHR': 81.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 14, 'Avg BR': 18.528977300739875, 'Avg IE ratio': 0.2839367698509186, 'Seq Var': 1.7843540264919853, 'Avg QoM': 11.472333069319207}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:52:00', 'Recording': 1, 'Initial Beat Count': 80, 'Cleaned Beat Count': 80, 'PC Removed': 0.0, 'Avg HR': 79.95469234100676, 'RMSSD': 18.89745813729013, 'Avg eqHR': 80.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 10, 'Avg BR': 13.524952653772933, 'Avg IE ratio': 0.20869578721852672, 'Seq Var': 1.518887162469865, 'Avg QoM': 11.59860646404831}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:53:00', 'Recording': 1, 'Initial Beat Count': 80, 'Cleaned Beat Count': 80, 'PC Removed': 0.0, 'Avg HR': 80.9088763779793, 'RMSSD': 17.525749591220833, 'Avg eqHR': 80.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 13, 'Avg BR': 16.719336056597424, 'Avg IE ratio': 0.3004666718860446, 'Seq Var': 1.5605381536841776, 'Avg QoM': 11.57721201527149}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:54:00', 'Recording': 1, 'Initial Beat Count': 80, 'Cleaned Beat Count': 80, 'PC Removed': 0.0, 'Avg HR': 79.97733975373644, 'RMSSD': 18.280168406281856, 'Avg eqHR': 79.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 17, 'Avg BR': 24.437256734629443, 'Avg IE ratio': 0.44744281902101235, 'Seq Var': 2.194166800909924, 'Avg QoM': 11.711931570534542}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:55:00', 'Recording': 1, 'Initial Beat Count': 78, 'Cleaned Beat Count': 78, 'PC Removed': 0.0, 'Avg HR': 78.07938070371544, 'RMSSD': 22.13535691996011, 'Avg eqHR': 77.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 11, 'Avg BR': 21.08747041505225, 'Avg IE ratio': 0.3274566795735856, 'Seq Var': 2.2684258781368505, 'Avg QoM': 11.397516533399475}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:56:00', 'Recording': 1, 'Initial Beat Count': 80, 'Cleaned Beat Count': 80, 'PC Removed': 0.0, 'Avg HR': 79.66143888473985, 'RMSSD': 21.749727191654436, 'Avg eqHR': 80.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 10, 'Avg BR': 12.104376561867014, 'Avg IE ratio': 0.1971600658169869, 'Seq Var': 1.471856560782556, 'Avg QoM': 11.485716440140854}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:57:00', 'Recording': 1, 'Initial Beat Count': 82, 'Cleaned Beat Count': 82, 'PC Removed': 0.0, 'Avg HR': 82.489437328147, 'RMSSD': 21.826758976252233, 'Avg eqHR': 82.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 12, 'Avg BR': 14.860022206832106, 'Avg IE ratio': 0.2775548309650905, 'Seq Var': 1.6498683123360025, 'Avg QoM': 11.498370445102262}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:58:00', 'Recording': 1, 'Initial Beat Count': 78, 'Cleaned Beat Count': 78, 'PC Removed': 0.0, 'Avg HR': 77.82877669127919, 'RMSSD': 21.091636798910198, 'Avg eqHR': 78.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 14, 'Avg BR': 15.71445106152556, 'Avg IE ratio': 0.3601723613846077, 'Seq Var': 1.3091462262329254, 'Avg QoM': 11.319801617249055}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:59:00', 'Recording': 1, 'Initial Beat Count': 80, 'Cleaned Beat Count': 80, 'PC Removed': 0.0, 'Avg HR': 79.43600436898024, 'RMSSD': 17.95423154523041, 'Avg eqHR': 79.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 15, 'Avg BR': 16.266654920600534, 'Avg IE ratio': 0.38808880020833514, 'Seq Var': 1.3386992715275214, 'Avg QoM': 11.370863951472787}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:00:00', 'Recording': 1, 'Initial Beat Count': 80, 'Cleaned Beat Count': 80, 'PC Removed': 0.0, 'Avg HR': 80.27024315194488, 'RMSSD': 17.378147196982766, 'Avg eqHR': 79.75, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 17, 'Avg BR': 21.981992053811208, 'Avg IE ratio': 0.3924092225228912, 'Seq Var': 1.5118141269124614, 'Avg QoM': 11.584647306287087}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:01:00', 'Recording': 1, 'Initial Beat Count': 85, 'Cleaned Beat Count': 85, 'PC Removed': 0.0, 'Avg HR': 84.81341049690681, 'RMSSD': 16.77938077068457, 'Avg eqHR': 84.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 16, 'Avg BR': 20.653374534027527, 'Avg IE ratio': 0.4337461141182445, 'Seq Var': 1.7726266224379013, 'Avg QoM': 11.923105971527873}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:02:00', 'Recording': 1, 'Initial Beat Count': 84, 'Cleaned Beat Count': 84, 'PC Removed': 0.0, 'Avg HR': 84.08268130328156, 'RMSSD': 13.071628432583221, 'Avg eqHR': 84.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 22, 'Avg BR': 22.764333023566714, 'Avg IE ratio': 0.4065658328313939, 'Seq Var': 1.29776448574531, 'Avg QoM': 11.045638395891334}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:03:00', 'Recording': 1, 'Initial Beat Count': 80, 'Cleaned Beat Count': 80, 'PC Removed': 0.0, 'Avg HR': 80.31725314994227, 'RMSSD': 20.03509578941761, 'Avg eqHR': 81.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 13, 'Avg BR': 19.980120102042182, 'Avg IE ratio': 0.4330101957812811, 'Seq Var': 1.6839568569353318, 'Avg QoM': 10.73692638054465}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:04:00', 'Recording': 1, 'Initial Beat Count': 81, 'Cleaned Beat Count': 81, 'PC Removed': 0.0, 'Avg HR': 81.03646640988445, 'RMSSD': 16.225751138237023, 'Avg eqHR': 80.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 19, 'Avg BR': 21.342004204599505, 'Avg IE ratio': 0.38837551183643215, 'Seq Var': 1.2728216148554992, 'Avg QoM': 10.514654153468225}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:05:00', 'Recording': 1, 'Initial Beat Count': 80, 'Cleaned Beat Count': 80, 'PC Removed': 0.0, 'Avg HR': 80.1268675402721, 'RMSSD': 27.30836566774068, 'Avg eqHR': 80.75, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 13, 'Avg BR': 16.56159361324849, 'Avg IE ratio': 0.37115769801944654, 'Seq Var': 1.9226814173470967, 'Avg QoM': 11.91298837424439}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:06:00', 'Recording': 1, 'Initial Beat Count': 81, 'Cleaned Beat Count': 81, 'PC Removed': 0.0, 'Avg HR': 81.34708087841457, 'RMSSD': 25.89280788172654, 'Avg eqHR': 80.75, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 18, 'Avg BR': 23.74528974324692, 'Avg IE ratio': 0.38767705444180967, 'Seq Var': 1.7689306838922236, 'Avg QoM': 11.438283300537444}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:07:00', 'Recording': 1, 'Initial Beat Count': 89, 'Cleaned Beat Count': 89, 'PC Removed': 0.0, 'Avg HR': 88.53959411062475, 'RMSSD': 10.880027573494472, 'Avg eqHR': 87.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 12, 'Avg BR': 15.56617080171047, 'Avg IE ratio': 0.3051962359675702, 'Seq Var': 1.90605032343252, 'Avg QoM': 11.643700155241406}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:08:00', 'Recording': 1, 'Initial Beat Count': 85, 'Cleaned Beat Count': 85, 'PC Removed': 0.0, 'Avg HR': 84.9164987762034, 'RMSSD': 19.901842460770645, 'Avg eqHR': 85.75, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 16, 'Avg BR': 19.89263978972543, 'Avg IE ratio': 0.38783519606991146, 'Seq Var': 1.4533611623551912, 'Avg QoM': 11.717676807451907}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:09:00', 'Recording': 1, 'Initial Beat Count': 83, 'Cleaned Beat Count': 83, 'PC Removed': 0.0, 'Avg HR': 83.27619939465895, 'RMSSD': 23.300528623753184, 'Avg eqHR': 84.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 12, 'Avg BR': 18.13698022375208, 'Avg IE ratio': 0.36113481033703043, 'Seq Var': 1.8811954096545878, 'Avg QoM': 11.39108801707614}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:10:00', 'Recording': 1, 'Initial Beat Count': 81, 'Cleaned Beat Count': 81, 'PC Removed': 0.0, 'Avg HR': 81.53131238571356, 'RMSSD': 21.478477599681035, 'Avg eqHR': 81.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 16, 'Avg BR': 25.00517759723615, 'Avg IE ratio': 0.39138186270352526, 'Seq Var': 2.0942236597377866, 'Avg QoM': 11.822800728866374}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:11:00', 'Recording': 1, 'Initial Beat Count': 83, 'Cleaned Beat Count': 83, 'PC Removed': 0.0, 'Avg HR': 82.46944656046104, 'RMSSD': 16.120733506279663, 'Avg eqHR': 81.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 15, 'Avg BR': 18.829537829774143, 'Avg IE ratio': 0.3422616623544556, 'Seq Var': 1.433244907180748, 'Avg QoM': 11.673405722425946}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:12:00', 'Recording': 1, 'Initial Beat Count': 77, 'Cleaned Beat Count': 77, 'PC Removed': 0.0, 'Avg HR': 77.22911303533817, 'RMSSD': 19.759075196769178, 'Avg eqHR': 78.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 15, 'Avg BR': 18.614931317350973, 'Avg IE ratio': 0.3787324371575299, 'Seq Var': 1.8223096807977832, 'Avg QoM': 11.820730206851074}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:13:00', 'Recording': 1, 'Initial Beat Count': 77, 'Cleaned Beat Count': 77, 'PC Removed': 0.0, 'Avg HR': 76.76841528057028, 'RMSSD': 22.96335753921199, 'Avg eqHR': 77.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 17, 'Avg BR': 19.772487369982063, 'Avg IE ratio': 0.3813107941700402, 'Seq Var': 1.405046872831823, 'Avg QoM': 11.609650195006834}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:14:00', 'Recording': 1, 'Initial Beat Count': 77, 'Cleaned Beat Count': 77, 'PC Removed': 0.0, 'Avg HR': 77.48167776342932, 'RMSSD': 30.187353573797647, 'Avg eqHR': 77.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 13, 'Avg BR': 17.919805961977293, 'Avg IE ratio': 0.2830408100874473, 'Seq Var': 1.9467200691646325, 'Avg QoM': 11.62991705012078}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:15:00', 'Recording': 1, 'Initial Beat Count': 80, 'Cleaned Beat Count': 80, 'PC Removed': 0.0, 'Avg HR': 80.2313336787738, 'RMSSD': 21.554758057948803, 'Avg eqHR': 79.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 15, 'Avg BR': 21.21725051004718, 'Avg IE ratio': 0.4234611528427886, 'Seq Var': 1.6695000764103658, 'Avg QoM': 11.928409065589953}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:16:00', 'Recording': 1, 'Initial Beat Count': 90, 'Cleaned Beat Count': 90, 'PC Removed': 0.0, 'Avg HR': 89.46173853978561, 'RMSSD': 14.672070846385262, 'Avg eqHR': 88.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 19, 'Avg BR': 27.46883306855302, 'Avg IE ratio': 0.4531875938533877, 'Seq Var': 1.8732432593736044, 'Avg QoM': 12.607738287602038}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:17:00', 'Recording': 1, 'Initial Beat Count': 89, 'Cleaned Beat Count': 89, 'PC Removed': 0.0, 'Avg HR': 88.99406706219585, 'RMSSD': 13.319926972226781, 'Avg eqHR': 88.75, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 20, 'Avg BR': 24.804716191891927, 'Avg IE ratio': 0.48435558501331777, 'Seq Var': 1.4920240080771228, 'Avg QoM': 13.099479098650878}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:18:00', 'Recording': 1, 'Initial Beat Count': 86, 'Cleaned Beat Count': 86, 'PC Removed': 0.0, 'Avg HR': 86.24868370468184, 'RMSSD': 24.59794348171025, 'Avg eqHR': 88.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 16, 'Avg BR': 22.40342100055019, 'Avg IE ratio': 0.4068345348968573, 'Seq Var': 1.9434790333780187, 'Avg QoM': 12.755754967166347}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:19:00', 'Recording': 1, 'Initial Beat Count': 84, 'Cleaned Beat Count': 84, 'PC Removed': 0.0, 'Avg HR': 84.3260607683041, 'RMSSD': 23.047881014902615, 'Avg eqHR': 82.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 14, 'Avg BR': 18.15413673580839, 'Avg IE ratio': 0.4579850983193765, 'Seq Var': 1.4908318197530839, 'Avg QoM': 12.144473789476486}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:20:00', 'Recording': 1, 'Initial Beat Count': 84, 'Cleaned Beat Count': 84, 'PC Removed': 0.0, 'Avg HR': 83.85604711911219, 'RMSSD': 13.444217640004466, 'Avg eqHR': 85.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 18, 'Avg BR': 22.119775439679664, 'Avg IE ratio': 0.48372231237345453, 'Seq Var': 1.275675428308399, 'Avg QoM': 12.566958979423335}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:21:00', 'Recording': 1, 'Initial Beat Count': 81, 'Cleaned Beat Count': 81, 'PC Removed': 0.0, 'Avg HR': 80.7966617346345, 'RMSSD': 23.61090849586267, 'Avg eqHR': 81.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 16, 'Avg BR': 22.213603652119673, 'Avg IE ratio': 0.40723404952719944, 'Seq Var': 1.847149971582251, 'Avg QoM': 12.101989375706756}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:22:00', 'Recording': 1, 'Initial Beat Count': 77, 'Cleaned Beat Count': 75, 'PC Removed': 2.6, 'Avg HR': 77.44067184085081, 'RMSSD': 20.415744698123245, 'Avg eqHR': 76.75, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 14, 'Avg BR': 17.696026536270605, 'Avg IE ratio': 0.3439784412880738, 'Seq Var': 1.5609623819871974, 'Avg QoM': 11.895948489204489}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:23:00', 'Recording': 1, 'Initial Beat Count': 82, 'Cleaned Beat Count': 82, 'PC Removed': 0.0, 'Avg HR': 82.32105210320249, 'RMSSD': 22.159912644120727, 'Avg eqHR': 82.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Prone', 'Breath Count': 17, 'Avg BR': 18.469807047728985, 'Avg IE ratio': 0.3798505141341791, 'Seq Var': 1.3319486698992615, 'Avg QoM': 11.854296212443945}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:24:00', 'Recording': 1, 'Initial Beat Count': 85, 'Cleaned Beat Count': 85, 'PC Removed': 0.0, 'Avg HR': 84.36166341350447, 'RMSSD': 20.41328932221314, 'Avg eqHR': 84.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 14, 'Avg BR': 16.647334969002593, 'Avg IE ratio': 0.35479380600827953, 'Seq Var': 1.4341713798451552, 'Avg QoM': 11.8420578710725}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:25:00', 'Recording': 1, 'Initial Beat Count': 85, 'Cleaned Beat Count': 85, 'PC Removed': 0.0, 'Avg HR': 85.00850085008501, 'RMSSD': 18.106825863666522, 'Avg eqHR': 84.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Prone', 'Breath Count': 15, 'Avg BR': 18.897949481580397, 'Avg IE ratio': 0.35972663768163005, 'Seq Var': 1.62185012624789, 'Avg QoM': 11.936061582495809}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:26:00', 'Recording': 1, 'Initial Beat Count': 84, 'Cleaned Beat Count': 83, 'PC Removed': 1.2, 'Avg HR': 84.12162162162163, 'RMSSD': 26.183219351518943, 'Avg eqHR': 84.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 19, 'Avg BR': 23.259270532592403, 'Avg IE ratio': 0.5063597023052273, 'Seq Var': 1.5729612573430196, 'Avg QoM': 12.772429209457528}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:27:00', 'Recording': 1, 'Initial Beat Count': 77, 'Cleaned Beat Count': 77, 'PC Removed': 0.0, 'Avg HR': 77.92207792207792, 'RMSSD': 23.004576203785835, 'Avg eqHR': 79.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 11, 'Avg BR': 15.3889351214856, 'Avg IE ratio': 0.2641914582123905, 'Seq Var': 2.2578663792080533, 'Avg QoM': 11.456306597632631}
# {'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 09:28:00', 'Recording': 1, 'Initial Beat Count': 74, 'Cleaned Beat Count': 74, 'PC Removed': 0.0, 'Avg HR': 73.55377377244716, 'RMSSD': 21.08105687350873, 'Avg eqHR': 73.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 12, 'Avg BR': 13.97462240594328, 'Avg IE ratio': 0.25521441335442946, 'Seq Var': 1.3415738093624676, 'Avg QoM': 10.810058150484698}

# %%
tstart = Excerpt_times.iloc[0].round('min')-pd.to_timedelta(60,'s')
samples = int(np.floor((Excerpt_times.iloc[-1]-tstart).total_seconds()/60))+1
print(samples)

t_int =60
sig_ex = sess_tag + ' '+ dev_tag
session_stats = {}
for i in range(samples): #17
    t = tstart+i*pd.to_timedelta(60,'s')
    # needs to be corrected when the files have the right correspondence    
    cht = (t-eqfiles.loc[recindex,'RecStart']).total_seconds()
    chx = cht+t_int
    
    interval_stats = {}
    interval_stats['Device'] = dev_tag
    interval_stats['Start Time'] = t.strftime('%Y/%m/%d %H:%M:%S')
    interval_stats['Recording'] = recindex
    
    Ex = C.query('c_sTime>@cht and c_sTime<@chx').copy()
    Ex = V.query('c_sTime>@cht and c_sTime<@chx').copy()
    interval_stats['Initial Beat Count'] = len(Ex)

    Ex = newIBI.query('time>@cht and time<@chx').copy()
    interval_stats['Cleaned Beat Count'] =Ex['IBI'].notna().sum()
    interval_stats['PC Removed'] = 100*np.round((interval_stats['Initial Beat Count'] - interval_stats['Cleaned Beat Count'])/interval_stats['Initial Beat Count'],3)
    interval_stats['Avg HR'] = HR_avg(Ex['IBI'])
    interval_stats['RMSSD'] =rmssd(Ex['IBI'])
    Ex = D.query('c_sTime>@cht and c_sTime<@chx').copy()
    interval_stats['Avg eqHR'] = Ex['HR(BPM)'].mean()
    interval_stats['Mode Motion'] = Ex['MOTION'].mode()[0]
    interval_stats['Mode Posture'] = Ex['BODY POSITION'].mode()[0]

    Ex = R.query('c_sTime>@cht and c_sTime<@chx').copy()
    Ex = Breaths.query('In>@cht and Ex<@chx').copy()
    interval_stats['Breath Count'] = len(Ex)
    interval_stats['Avg BR'] =(60/Ex['Period_T']).mean()
    interval_stats['Avg IE ratio'] =(Ex['IE_Ratio']).mean()
    interval_stats['Seq Var'] =np.power(10,np.log10((Ex['Period_T']/Ex['Period_T'].shift(-1))).abs().mean())


    Ex = A.query('c_sTime>@cht and c_sTime<@chx').copy()
    interval_stats['Avg QoM'] =Ex['QoM'].mean()
    print(interval_stats)
    session_stats[t.strftime('%Y/%m/%d %H:%M:%S')] = interval_stats
Evaluated_Intervals =pd.DataFrame(data=session_stats).transpose()
Evaluated_Intervals.to_csv('_'.join(['./outfiles/'+sess_tag,dev_tag,'minutestats.csv']))
# Out:
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:32:00', 'Recording': 0, 'Initial Beat Count': 60, 'Cleaned Beat Count': 60, 'PC Removed': 0.0, 'Avg HR': 59.2582838142582, 'RMSSD': 37.76398607228581, 'Avg eqHR': 59.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 18, 'Avg BR': 20.18599524274411, 'Avg IE ratio': 0.30408207667873993, 'Seq Var': 1.3081973181834647, 'Avg QoM': 12.064224210337118}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:33:00', 'Recording': 0, 'Initial Beat Count': 61, 'Cleaned Beat Count': 61, 'PC Removed': 0.0, 'Avg HR': 61.696138091465365, 'RMSSD': 31.401963845169515, 'Avg eqHR': 61.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 17, 'Avg BR': 19.179386398409925, 'Avg IE ratio': 0.3814189755949434, 'Seq Var': 1.4346904740977393, 'Avg QoM': 12.035603750516467}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:34:00', 'Recording': 0, 'Initial Beat Count': 59, 'Cleaned Beat Count': 59, 'PC Removed': 0.0, 'Avg HR': 59.09257837278403, 'RMSSD': 43.39334924410295, 'Avg eqHR': 58.75, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 15, 'Avg BR': 17.10242909383376, 'Avg IE ratio': 0.2631558928252449, 'Seq Var': 1.3486200668428598, 'Avg QoM': 12.134961325609003}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:35:00', 'Recording': 0, 'Initial Beat Count': 68, 'Cleaned Beat Count': 68, 'PC Removed': 0.0, 'Avg HR': 67.58099781355595, 'RMSSD': 24.7223386808519, 'Avg eqHR': 65.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 22, 'Avg BR': 26.329668455632568, 'Avg IE ratio': 0.4705346239631765, 'Seq Var': 1.502775762287838, 'Avg QoM': 13.423928217528813}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:36:00', 'Recording': 0, 'Initial Beat Count': 66, 'Cleaned Beat Count': 66, 'PC Removed': 0.0, 'Avg HR': 66.29501280699111, 'RMSSD': 18.695536283377294, 'Avg eqHR': 68.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 21, 'Avg BR': 24.618161927866566, 'Avg IE ratio': 0.3471203910109991, 'Seq Var': 1.2877357331618595, 'Avg QoM': 12.1372371121884}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:37:00', 'Recording': 0, 'Initial Beat Count': 65, 'Cleaned Beat Count': 65, 'PC Removed': 0.0, 'Avg HR': 65.04661674199843, 'RMSSD': 21.133504205408055, 'Avg eqHR': 65.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 16, 'Avg BR': 19.179515413106344, 'Avg IE ratio': 0.556961522508054, 'Seq Var': 1.5932355051763398, 'Avg QoM': 12.540302035785754}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:38:00', 'Recording': 0, 'Initial Beat Count': 64, 'Cleaned Beat Count': 64, 'PC Removed': 0.0, 'Avg HR': 63.364245404442094, 'RMSSD': 32.43014470695877, 'Avg eqHR': 63.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 15, 'Avg BR': 20.01366637689654, 'Avg IE ratio': 0.3272873541760199, 'Seq Var': 1.8961485789750514, 'Avg QoM': 12.08775765288003}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:39:00', 'Recording': 0, 'Initial Beat Count': 63, 'Cleaned Beat Count': 63, 'PC Removed': 0.0, 'Avg HR': 63.098854872633794, 'RMSSD': 27.092732033374894, 'Avg eqHR': 62.75, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 16, 'Avg BR': 19.45577118065625, 'Avg IE ratio': 0.2432877311760866, 'Seq Var': 1.5141679002318107, 'Avg QoM': 12.296305706353685}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:40:00', 'Recording': 0, 'Initial Beat Count': 65, 'Cleaned Beat Count': 65, 'PC Removed': 0.0, 'Avg HR': 65.1639960567428, 'RMSSD': 26.43594853603706, 'Avg eqHR': 64.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 17, 'Avg BR': 23.78747433939262, 'Avg IE ratio': 0.41160786171989666, 'Seq Var': 1.973884988344052, 'Avg QoM': 12.485929495089442}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:41:00', 'Recording': 0, 'Initial Beat Count': 63, 'Cleaned Beat Count': 63, 'PC Removed': 0.0, 'Avg HR': 63.74905135340248, 'RMSSD': 27.11296559260544, 'Avg eqHR': 65.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 20, 'Avg BR': 22.341303322865887, 'Avg IE ratio': 0.40000991175216455, 'Seq Var': 1.279479280636406, 'Avg QoM': 12.422671145234217}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:42:00', 'Recording': 0, 'Initial Beat Count': 63, 'Cleaned Beat Count': 63, 'PC Removed': 0.0, 'Avg HR': 62.292974736738024, 'RMSSD': 29.36011118903091, 'Avg eqHR': 61.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 21, 'Avg BR': 24.679345142154883, 'Avg IE ratio': 0.3349072828688393, 'Seq Var': 1.5005334906427525, 'Avg QoM': 12.190857806854602}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:43:00', 'Recording': 0, 'Initial Beat Count': 58, 'Cleaned Beat Count': 58, 'PC Removed': 0.0, 'Avg HR': 57.98260521843447, 'RMSSD': 34.300785117094954, 'Avg eqHR': 59.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 17, 'Avg BR': 20.73605669822631, 'Avg IE ratio': 0.42457556372915284, 'Seq Var': 1.5302496217097383, 'Avg QoM': 12.068513329931307}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:44:00', 'Recording': 0, 'Initial Beat Count': 60, 'Cleaned Beat Count': 60, 'PC Removed': 0.0, 'Avg HR': 59.984004265529194, 'RMSSD': 43.3370706775995, 'Avg eqHR': 59.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 14, 'Avg BR': 16.778321674506, 'Avg IE ratio': 0.2764689423988537, 'Seq Var': 1.4842488699737817, 'Avg QoM': 12.226277501084034}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:45:00', 'Recording': 0, 'Initial Beat Count': 61, 'Cleaned Beat Count': 61, 'PC Removed': 0.0, 'Avg HR': 61.73776630737311, 'RMSSD': 34.50265690252467, 'Avg eqHR': 61.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 15, 'Avg BR': 19.045052209725245, 'Avg IE ratio': 0.2519257486220965, 'Seq Var': 1.4233639603409565, 'Avg QoM': 12.229749523347818}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:46:00', 'Recording': 0, 'Initial Beat Count': 63, 'Cleaned Beat Count': 63, 'PC Removed': 0.0, 'Avg HR': 63.204360766478274, 'RMSSD': 30.94062993290798, 'Avg eqHR': 62.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 18, 'Avg BR': 25.814278929395478, 'Avg IE ratio': 0.48586439771145495, 'Seq Var': 1.9186656833408802, 'Avg QoM': 12.27733365699696}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:47:00', 'Recording': 0, 'Initial Beat Count': 64, 'Cleaned Beat Count': 64, 'PC Removed': 0.0, 'Avg HR': 63.144393468501804, 'RMSSD': 30.00185179469946, 'Avg eqHR': 64.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 18, 'Avg BR': 23.823067494451763, 'Avg IE ratio': 0.6262579339566731, 'Seq Var': 2.062832380236593, 'Avg QoM': 12.606030582105227}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:48:00', 'Recording': 0, 'Initial Beat Count': 59, 'Cleaned Beat Count': 59, 'PC Removed': 0.0, 'Avg HR': 59.77003731406285, 'RMSSD': 35.67235962729842, 'Avg eqHR': 60.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 18, 'Avg BR': 22.487738785091146, 'Avg IE ratio': 0.4081157156495346, 'Seq Var': 1.6973211238868406, 'Avg QoM': 11.612449601804725}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:49:00', 'Recording': 0, 'Initial Beat Count': 59, 'Cleaned Beat Count': 59, 'PC Removed': 0.0, 'Avg HR': 58.8841944176453, 'RMSSD': 41.310848537600286, 'Avg eqHR': 57.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 21, 'Avg BR': 24.884481027406142, 'Avg IE ratio': 0.39797863534211575, 'Seq Var': 1.4221680298103438, 'Avg QoM': 11.826963373098973}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:50:00', 'Recording': 0, 'Initial Beat Count': 61, 'Cleaned Beat Count': 61, 'PC Removed': 0.0, 'Avg HR': 60.46089039398695, 'RMSSD': 38.095494046759214, 'Avg eqHR': 61.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 21, 'Avg BR': 26.98213405272448, 'Avg IE ratio': 0.5210958913921783, 'Seq Var': 1.79781069318797, 'Avg QoM': 12.24048214979097}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:51:00', 'Recording': 0, 'Initial Beat Count': 60, 'Cleaned Beat Count': 60, 'PC Removed': 0.0, 'Avg HR': 60.34497209045041, 'RMSSD': 35.140637540882224, 'Avg eqHR': 59.75, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 21, 'Avg BR': 22.36620968851703, 'Avg IE ratio': 0.32806758312602313, 'Seq Var': 1.3718133461406745, 'Avg QoM': 12.070311215859473}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:52:00', 'Recording': 0, 'Initial Beat Count': 62, 'Cleaned Beat Count': 62, 'PC Removed': 0.0, 'Avg HR': 62.58517135214253, 'RMSSD': 27.708080137714933, 'Avg eqHR': 62.75, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 18, 'Avg BR': 20.652217423069263, 'Avg IE ratio': 0.21203430351620842, 'Seq Var': 1.5934544092576182, 'Avg QoM': 12.047698539744228}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:53:00', 'Recording': 0, 'Initial Beat Count': 63, 'Cleaned Beat Count': 63, 'PC Removed': 0.0, 'Avg HR': 62.089356110381075, 'RMSSD': 28.337539219774502, 'Avg eqHR': 62.75, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 21, 'Avg BR': 26.057613167546098, 'Avg IE ratio': 0.3441792984674692, 'Seq Var': 1.5980514386403473, 'Avg QoM': 12.077630807745683}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:54:00', 'Recording': 0, 'Initial Beat Count': 60, 'Cleaned Beat Count': 60, 'PC Removed': 0.0, 'Avg HR': 60.03702283074563, 'RMSSD': 35.49194227006596, 'Avg eqHR': 60.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 23, 'Avg BR': 26.57481999149237, 'Avg IE ratio': 0.41657174148689685, 'Seq Var': 1.4309274867595922, 'Avg QoM': 12.08967169071621}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:55:00', 'Recording': 0, 'Initial Beat Count': 60, 'Cleaned Beat Count': 60, 'PC Removed': 0.0, 'Avg HR': 60.16042780748663, 'RMSSD': 36.079244232754924, 'Avg eqHR': 59.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 22, 'Avg BR': 24.954175663605653, 'Avg IE ratio': 0.33546249729358313, 'Seq Var': 1.4601469572154486, 'Avg QoM': 11.851794667105382}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:56:00', 'Recording': 0, 'Initial Beat Count': 60, 'Cleaned Beat Count': 60, 'PC Removed': 0.0, 'Avg HR': 60.21980227831585, 'RMSSD': 32.58418041871427, 'Avg eqHR': 60.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 19, 'Avg BR': 26.765599927558068, 'Avg IE ratio': 0.3707961492641467, 'Seq Var': 1.6631698592980482, 'Avg QoM': 12.27033111232339}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:57:00', 'Recording': 0, 'Initial Beat Count': 61, 'Cleaned Beat Count': 61, 'PC Removed': 0.0, 'Avg HR': 61.48780323902963, 'RMSSD': 26.397600901092005, 'Avg eqHR': 60.75, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 21, 'Avg BR': 24.173276856741406, 'Avg IE ratio': 0.33790337447664603, 'Seq Var': 1.5254169800073127, 'Avg QoM': 12.278558289992889}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:58:00', 'Recording': 0, 'Initial Beat Count': 61, 'Cleaned Beat Count': 61, 'PC Removed': 0.0, 'Avg HR': 60.83574349257006, 'RMSSD': 30.064652556338203, 'Avg eqHR': 62.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 23, 'Avg BR': 26.181299167951874, 'Avg IE ratio': 0.284736550936984, 'Seq Var': 1.3693061903749653, 'Avg QoM': 12.151240106898456}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 08:59:00', 'Recording': 0, 'Initial Beat Count': 60, 'Cleaned Beat Count': 59, 'PC Removed': 1.7000000000000002, 'Avg HR': 60.79758183629306, 'RMSSD': 36.65505722733199, 'Avg eqHR': 60.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 15, 'Avg BR': 19.175911287445786, 'Avg IE ratio': 0.21644469829233828, 'Seq Var': 1.5596176556461299, 'Avg QoM': 12.352593704558313}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:00:00', 'Recording': 0, 'Initial Beat Count': 64, 'Cleaned Beat Count': 64, 'PC Removed': 0.0, 'Avg HR': 64.44574976923722, 'RMSSD': 29.511095572763168, 'Avg eqHR': 63.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 14, 'Avg BR': 19.135032180970065, 'Avg IE ratio': 0.45272721646358954, 'Seq Var': 1.8372612743609988, 'Avg QoM': 13.341307290248702}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:01:00', 'Recording': 0, 'Initial Beat Count': 63, 'Cleaned Beat Count': 63, 'PC Removed': 0.0, 'Avg HR': 62.294001318391565, 'RMSSD': 26.543634192194414, 'Avg eqHR': 62.75, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 18, 'Avg BR': 22.5144808537481, 'Avg IE ratio': 0.3354818492189005, 'Seq Var': 1.6325468888326167, 'Avg QoM': 12.551424012215502}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:02:00', 'Recording': 0, 'Initial Beat Count': 62, 'Cleaned Beat Count': 62, 'PC Removed': 0.0, 'Avg HR': 62.367971029071526, 'RMSSD': 31.19951659987016, 'Avg eqHR': 62.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 24, 'Avg BR': 27.628635370891896, 'Avg IE ratio': 0.5036135334813656, 'Seq Var': 1.454056035295621, 'Avg QoM': 12.369691442846158}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:03:00', 'Recording': 0, 'Initial Beat Count': 58, 'Cleaned Beat Count': 58, 'PC Removed': 0.0, 'Avg HR': 58.46184860397137, 'RMSSD': 32.87589635893612, 'Avg eqHR': 59.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 24, 'Avg BR': 26.997572665164324, 'Avg IE ratio': 0.39900325049865976, 'Seq Var': 1.3321521471137365, 'Avg QoM': 12.353549909882672}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:04:00', 'Recording': 0, 'Initial Beat Count': 62, 'Cleaned Beat Count': 62, 'PC Removed': 0.0, 'Avg HR': 61.80839397866613, 'RMSSD': 34.849794787362974, 'Avg eqHR': 61.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 23, 'Avg BR': 29.905522878998745, 'Avg IE ratio': 0.5934736501168275, 'Seq Var': 1.7908125779666613, 'Avg QoM': 12.190738831507554}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:05:00', 'Recording': 0, 'Initial Beat Count': 59, 'Cleaned Beat Count': 59, 'PC Removed': 0.0, 'Avg HR': 59.026561952878794, 'RMSSD': 37.99795820285883, 'Avg eqHR': 59.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 18, 'Avg BR': 20.860117871674344, 'Avg IE ratio': 0.2778942253273803, 'Seq Var': 1.379229940882812, 'Avg QoM': 12.344690373794405}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:06:00', 'Recording': 0, 'Initial Beat Count': 59, 'Cleaned Beat Count': 59, 'PC Removed': 0.0, 'Avg HR': 58.93615250145675, 'RMSSD': 42.505172099080056, 'Avg eqHR': 58.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Prone', 'Breath Count': 21, 'Avg BR': 22.583995991837202, 'Avg IE ratio': 0.47326081251569235, 'Seq Var': 1.425904005284312, 'Avg QoM': 12.174712407589311}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:07:00', 'Recording': 0, 'Initial Beat Count': 61, 'Cleaned Beat Count': 61, 'PC Removed': 0.0, 'Avg HR': 60.50686901750731, 'RMSSD': 36.302433343602004, 'Avg eqHR': 60.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Prone', 'Breath Count': 21, 'Avg BR': 22.60175379799054, 'Avg IE ratio': 0.476888416285467, 'Seq Var': 1.2875125127283418, 'Avg QoM': 12.008147744512007}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:08:00', 'Recording': 0, 'Initial Beat Count': 63, 'Cleaned Beat Count': 63, 'PC Removed': 0.0, 'Avg HR': 62.991601119850685, 'RMSSD': 25.310331946179737, 'Avg eqHR': 62.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Prone', 'Breath Count': 12, 'Avg BR': 16.7535677692122, 'Avg IE ratio': 0.2759341590137423, 'Seq Var': 1.7536634460553218, 'Avg QoM': 12.23437493608204}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:09:00', 'Recording': 0, 'Initial Beat Count': 64, 'Cleaned Beat Count': 64, 'PC Removed': 0.0, 'Avg HR': 64.86376919308796, 'RMSSD': 21.64687740962427, 'Avg eqHR': 65.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 15, 'Avg BR': 20.78162524596481, 'Avg IE ratio': 0.3449293160317059, 'Seq Var': 1.8374470121079163, 'Avg QoM': 11.932455300503014}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:10:00', 'Recording': 0, 'Initial Beat Count': 60, 'Cleaned Beat Count': 60, 'PC Removed': 0.0, 'Avg HR': 60.04202942059442, 'RMSSD': 36.251008168330145, 'Avg eqHR': 60.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 14, 'Avg BR': 21.095392479210194, 'Avg IE ratio': 0.45261990790518586, 'Seq Var': 2.4413565866297966, 'Avg QoM': 12.44384057942987}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:11:00', 'Recording': 0, 'Initial Beat Count': 59, 'Cleaned Beat Count': 59, 'PC Removed': 0.0, 'Avg HR': 58.91065217753074, 'RMSSD': 35.80382372182402, 'Avg eqHR': 58.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 18, 'Avg BR': 25.369304946119772, 'Avg IE ratio': 0.546520078518959, 'Seq Var': 1.7392388008387114, 'Avg QoM': 12.987814924681851}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:12:00', 'Recording': 0, 'Initial Beat Count': 61, 'Cleaned Beat Count': 61, 'PC Removed': 0.0, 'Avg HR': 60.851926977687626, 'RMSSD': 27.913557040740375, 'Avg eqHR': 60.75, 'Mode Motion': 'Stationary', 'Mode Posture': 'Prone', 'Breath Count': 19, 'Avg BR': 22.405517033521193, 'Avg IE ratio': 0.39801051455523284, 'Seq Var': 1.4650647456299006, 'Avg QoM': 12.45605956028259}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:13:00', 'Recording': 0, 'Initial Beat Count': 64, 'Cleaned Beat Count': 64, 'PC Removed': 0.0, 'Avg HR': 63.569844055226305, 'RMSSD': 24.259836820137156, 'Avg eqHR': 63.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 20, 'Avg BR': 26.47147677109701, 'Avg IE ratio': 0.3291074810301647, 'Seq Var': 1.6982727365382002, 'Avg QoM': 12.99838028311869}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:14:00', 'Recording': 0, 'Initial Beat Count': 62, 'Cleaned Beat Count': 62, 'PC Removed': 0.0, 'Avg HR': 62.21255957856008, 'RMSSD': 33.521708161022865, 'Avg eqHR': 62.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 14, 'Avg BR': 21.062292673506313, 'Avg IE ratio': 0.40276729033303693, 'Seq Var': 2.059286870180691, 'Avg QoM': 12.614842540115761}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:15:00', 'Recording': 0, 'Initial Beat Count': 62, 'Cleaned Beat Count': 62, 'PC Removed': 0.0, 'Avg HR': 62.02998115755949, 'RMSSD': 24.410760862817025, 'Avg eqHR': 62.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Prone', 'Breath Count': 19, 'Avg BR': 24.551699075231273, 'Avg IE ratio': 0.39521861592976143, 'Seq Var': 1.624876313752715, 'Avg QoM': 12.43461844687315}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:16:00', 'Recording': 0, 'Initial Beat Count': 64, 'Cleaned Beat Count': 64, 'PC Removed': 0.0, 'Avg HR': 64.05978913652743, 'RMSSD': 33.324760802437616, 'Avg eqHR': 64.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 21, 'Avg BR': 26.093970751391083, 'Avg IE ratio': 0.43187704545859934, 'Seq Var': 1.5963394653109018, 'Avg QoM': 12.231235851338655}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:17:00', 'Recording': 0, 'Initial Beat Count': 61, 'Cleaned Beat Count': 61, 'PC Removed': 0.0, 'Avg HR': 61.31269474319027, 'RMSSD': 26.573796617470123, 'Avg eqHR': 61.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 21, 'Avg BR': 25.64342845695918, 'Avg IE ratio': 0.45387665213282763, 'Seq Var': 1.5867051786674977, 'Avg QoM': 12.483857376810416}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:18:00', 'Recording': 0, 'Initial Beat Count': 61, 'Cleaned Beat Count': 61, 'PC Removed': 0.0, 'Avg HR': 61.188665050572595, 'RMSSD': 42.4976469936866, 'Avg eqHR': 61.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 14, 'Avg BR': 16.723242887618124, 'Avg IE ratio': 0.48606516397090554, 'Seq Var': 1.7753125925258684, 'Avg QoM': 12.967838803970857}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:19:00', 'Recording': 0, 'Initial Beat Count': 61, 'Cleaned Beat Count': 61, 'PC Removed': 0.0, 'Avg HR': 60.51887494419366, 'RMSSD': 31.433262636894693, 'Avg eqHR': 61.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 14, 'Avg BR': 17.870960949361564, 'Avg IE ratio': 0.3964633973964934, 'Seq Var': 1.7363251683602885, 'Avg QoM': 12.626158990686019}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:20:00', 'Recording': 0, 'Initial Beat Count': 57, 'Cleaned Beat Count': 57, 'PC Removed': 0.0, 'Avg HR': 56.9421088559964, 'RMSSD': 38.75218887827038, 'Avg eqHR': 57.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 25, 'Avg BR': 26.009301866001582, 'Avg IE ratio': 0.45749310312444236, 'Seq Var': 1.0941690487597393, 'Avg QoM': 11.544661713235042}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:21:00', 'Recording': 0, 'Initial Beat Count': 59, 'Cleaned Beat Count': 59, 'PC Removed': 0.0, 'Avg HR': 59.69847212384904, 'RMSSD': 33.856186721341565, 'Avg eqHR': 58.5, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 25, 'Avg BR': 30.483563869325376, 'Avg IE ratio': 0.6380685104818423, 'Seq Var': 1.4763625459033978, 'Avg QoM': 12.407330282208079}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:22:00', 'Recording': 0, 'Initial Beat Count': 61, 'Cleaned Beat Count': 61, 'PC Removed': 0.0, 'Avg HR': 60.9380463195751, 'RMSSD': 38.91465019757983, 'Avg eqHR': 61.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Prone', 'Breath Count': 17, 'Avg BR': 19.387521918224813, 'Avg IE ratio': 0.40836643299552494, 'Seq Var': 1.4270786811191927, 'Avg QoM': 12.434875683453326}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:23:00', 'Recording': 0, 'Initial Beat Count': 58, 'Cleaned Beat Count': 58, 'PC Removed': 0.0, 'Avg HR': 58.155080213903744, 'RMSSD': 42.56986002391998, 'Avg eqHR': 58.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 22, 'Avg BR': 25.723987633348486, 'Avg IE ratio': 0.5144026657875078, 'Seq Var': 1.4708223222326944, 'Avg QoM': 12.281871023584605}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:24:00', 'Recording': 0, 'Initial Beat Count': 59, 'Cleaned Beat Count': 59, 'PC Removed': 0.0, 'Avg HR': 58.35902339306616, 'RMSSD': 43.980991191728464, 'Avg eqHR': 59.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 16, 'Avg BR': 21.558903858209398, 'Avg IE ratio': 0.3529642634473038, 'Seq Var': 1.9696586440805002, 'Avg QoM': 12.244443279442988}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:25:00', 'Recording': 0, 'Initial Beat Count': 60, 'Cleaned Beat Count': 60, 'PC Removed': 0.0, 'Avg HR': 60.278284747919564, 'RMSSD': 35.561596120591496, 'Avg eqHR': 59.0, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 23, 'Avg BR': 26.80407917014718, 'Avg IE ratio': 0.4782259392815376, 'Seq Var': 1.576964421051579, 'Avg QoM': 12.478442525222532}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:26:00', 'Recording': 0, 'Initial Beat Count': 60, 'Cleaned Beat Count': 60, 'PC Removed': 0.0, 'Avg HR': 59.837441616940644, 'RMSSD': 44.367303581789194, 'Avg eqHR': 60.75, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 12, 'Avg BR': 16.717709297830694, 'Avg IE ratio': 0.4475827931501594, 'Seq Var': 1.716608675186352, 'Avg QoM': 12.263996183664174}
# {'Device': 'BLUETOOTH01', 'Start Time': '2023/05/24 09:27:00', 'Recording': 0, 'Initial Beat Count': 61, 'Cleaned Beat Count': 61, 'PC Removed': 0.0, 'Avg HR': 61.20503687352632, 'RMSSD': 42.67180958587687, 'Avg eqHR': 59.75, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 21, 'Avg BR': 22.234460512175268, 'Avg IE ratio': 0.38021747782813664, 'Seq Var': 1.2770211880168039, 'Avg QoM': 12.436464499982177}

# %%
'Device': 'BLUETOOTH03', 'Start Time': '2023/05/24 08:32:00', 'Recording': 1, 'Initial Beat Count': 78, 'Cleaned Beat Count': 78, 'PC Removed': 0.0, 'Avg HR': 78.7998181542658, 'RMSSD': 35.25012664617574, 'Avg eqHR': 79.25, 'Mode Motion': 'Stationary', 'Mode Posture': 'Upright', 'Breath Count': 9, 'Avg BR': 11.287992382661477, 'Avg IE ratio': 0.3912001178495901, 'Seq Var': 1.515755706113264, 'Avg QoM': 11.090932875451958}

# %%
fig, (ax) = plt.subplots(7, 1,figsize = [15,10])
ax[0].plot(C['c_sTime'],C[[' Lead 1',' Lead 2']],label=[' Lead 1',' Lead 2'])
ax[0].set_title(sess_tag + ' session, '+ dev_tag +' EGC, devIBI cleaning, Resp, full raw recording' )
ax[0].set(ylabel = 'ECG',xticks = Exticks,xlim = xrange,ylim = [-2,2])
ax[0].grid()
ax[0].legend()

ax[1].scatter(x =sig_t,y=(60000/sig_v),color='r',alpha = 0.2,label='EQ Single Beat')
ax[1].scatter(x = IBI.index,y = (60000/IBI['IBI']),color='b',alpha = 0.2,label='cleaned')
ax[1].scatter(x =newV['c_sTime'],y=(60000/newV[' Interbeat Interval (MS)']),color='c',marker = 'v',alpha = 0.8,label='cleared')
ax[1].scatter(x = newIBI.index,y = (60000/newIBI['IBI']),color='y',marker = '+',alpha = 0.8,label='cleared+cleaned')
ax[1].grid()
ax[1].legend()
ax[1].plot(D['c_sTime'],D['HR(BPM)'],alpha=0.7,c='k',label='EQHR')
ax[1].set(ylabel='BPM',ylim=[35,135],xticks = Exticks, xlim = xrange)

ax[2].plot(R['c_sTime'],R[' Breathing'],color = 'b',label='Respiration')
ax[2].set(xlabel = 'Time (s), Session',ylabel = 'RespWave',xticks = Exticks,xlim = xrange,ylim = [0,1024])
ax[2].grid()
ax[2].legend()

ax[3].plot(A['c_sTime'],A['QoM'],color = 'g',label='Quantity of Motion')
ax[3].set(xticks = Exticks,ylabel = 'Body Jerk',ylim = [0,250], xlim = xrange)
ax[3].grid()
ax[3].legend()
chart = sns.heatmap(data=spec[' Vert Accelerometer'].loc[:,Hz[::-1]].transpose(),vmin=0, vmax=80,cmap="cubehelix", cbar = False, ax=ax[4])
ax[4].set(xticks = [],yticks=[],ylabel='Vert Spec')
chart = sns.heatmap(data=spec[' Long Accelerometer'].loc[:,Hz[::-1]].transpose(),vmin=0, vmax=80,cmap="cubehelix", cbar = False, ax=ax[5])
ax[5].set(xticks = [],yticks=[],ylabel='Long Spec')
chart = sns.heatmap(data=spec[' Lat Accelerometer'].loc[:,Hz[::-1]].transpose(),vmin=0, vmax=80,cmap="cubehelix",cbar = False,  ax=ax[6])
ax[6].set(xticks = [],yticks=[],ylabel='Lat Spec')
plt.savefig('_'.join(['./plots/'+sess_tag + '/'+sess_tag,'FullRec',dev_tag+'.jpg']))
plt.show()

# %%
t_int =60
sig_ex = sess_tag + ' '+ dev_tag
session_stats = {}
for t in Excerpt_times: #17
    # needs to be corrected when the files have the right correspondence    
    cht = (t-eqfiles.loc[recindex,'RecStart']).total_seconds()
    chx = cht+t_int
    
    interval_stats = {}
    interval_stats['Device'] = dev_tag
    interval_stats['Start Time'] = t.strftime('%Y/%m/%d %H:%M:%S')
    interval_stats['Recording'] = recindex
    
    fig, (ax) = plt.subplots(4, 1,figsize = [12,5],sharex = True)
    Ex = C.query('c_sTime>@cht and c_sTime<@chx').copy()
    ax[0].plot(Ex['c_sTime'],Ex[' Lead 1']-0.5)
    ax[0].plot(Ex['c_sTime'],Ex[' Lead 2']+0.5)
    ax[0].set_ylabel('ECG')
    ax[0].set_title(sig_ex +' EGC, devIBI, Resp ' + t.strftime('%H:%M:%S') )
    ax[0].set_xlim([cht,chx])
#     ax[0].set_ylim([-1.5,1.5])
    Ex = V.query('c_sTime>@cht and c_sTime<@chx').copy()
    interval_stats['Initial Beat Count'] = len(Ex)

    ax[1].scatter(x =Ex['c_sTime'],y=(Ex[' Interbeat Interval (MS)']/1000),color='r',alpha = 0.2,label='Single Beat')
    Ex = newIBI.query('time>@cht and time<@chx').copy()
    interval_stats['Cleaned Beat Count'] =Ex['IBI'].notna().sum()
    interval_stats['PC Removed'] = 100*np.round((interval_stats['Initial Beat Count'] - interval_stats['Cleaned Beat Count'])/interval_stats['Initial Beat Count'],3)
    ax[1].scatter(x = Ex.index,y = Ex['IBI']/1000,color='m',marker = '+',alpha = 0.8,label='cleared+cleaned')
    interval_stats['Avg HR'] = HR_avg(Ex['IBI'])
    interval_stats['RMSSD'] =rmssd(Ex['IBI'])
    Ex = D.query('c_sTime>@cht and c_sTime<@chx').copy()
    interval_stats['Avg eqHR'] = Ex['HR(BPM)'].mean()
    interval_stats['Mode Motion'] = Ex['MOTION'].mode()[0]
    interval_stats['Mode Posture'] = Ex['BODY POSITION'].mode()[0]
#     ax[1].plot(D['c_sTime'],60/D['HR(BPM)'],alpha=0.7,c='k',label='EQHR')
#     ax[1].legend()
    ax[1].set_ylabel('rr (s)')
#     ax[1].set_ylim([400,1400])

    Ex = R.query('c_sTime>@cht and c_sTime<@chx').copy()
    ax[2].plot(Ex['c_sTime'],Ex[' Breathing'],color = 'b',label='Respiration')
    Ex = Breaths.query('In>@cht and Ex<@chx').copy()
    ax[2].scatter(Ex['In'],Ex['In_C'])
    ax[2].scatter(Ex['Ex'],Ex['Ex_C'])
    ax[2].set_ylabel('RespWave')
    interval_stats['Breath Count'] = len(Ex)
    interval_stats['Avg BR'] =(60/Ex['Period_T'].mean())
    interval_stats['Avg IE ratio'] =(Ex['IE_Ratio'].mean())
    interval_stats['Seq Var'] =np.power(10,np.log10((Ex['Period_T']/Ex['Period_T'].shift(-1))).abs().mean())


    Ex = A.query('c_sTime>@cht and c_sTime<@chx').copy()
    ax[3].plot(Ex['c_sTime'],Ex['QoM'],color = 'g',label='Quantity of Motion')
    ax[3].set(xlabel = 'Time (s), session',ylabel = 'Body Jerk',ylim = [0,120])
    interval_stats['Avg QoM'] =Ex['QoM'].mean()

    ax[3].grid()
    ax[2].grid()
    ax[1].grid()
    ax[0].grid()
    print(interval_stats)
    session_stats[t.strftime('%Y/%m/%d %H:%M:%S')] = interval_stats
    plt.savefig('_'.join(['./plots/'+sess_tag + '/'+sess_tag,t.strftime('%H%M%S'),dev_tag,'excerpt.jpg']))
    plt.show()

Evaluated_Intervals =pd.DataFrame(data=session_stats).transpose()
# Evaluated_Intervals.to_csv('_'.join(['./outfiles/'+sess_tag,dev_tag,'fullstats.csv']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 t_int =60
# ----> 2 sig_ex = sess_tag + ' '+ dev_tag
#       3 session_stats = {}
#       4 for t in Excerpt_times: #17
#       5     # needs to be corrected when the files have the right correspondence
#
# NameError: name 'sess_tag' is not defined

# %%
Evs.append(Evaluated_Intervals.copy())

# %%
Ex_stats = pd.concat(Evs)

# %%
        sig_v_pre = np.log2(sig_v/sig_v.shift(1)).abs()
        sig_v_post = np.log2(sig_v.shift(-1)/sig_v).abs()
        sig_v = sig_v.mask((sig_v_post>0.15) & (sig_v_pre>0.15))

# %%
[(2**1.15)-2,(2**0.85)-2]
# Out:
# [0.21913894413568968, -0.1974990747783396]

# %% [markdown]
# Dan recommended to check manually a very small sample (5 or 10 intervals) at the start of the process. He also wondered if there was a way to track how many artefacts are detected (to be able to report in the article that f.ex "on average, 2% of beats were detected as artefacts"). With regards to respiration, he thought that respiration rate would be best to use as a control - Finn, this is your area of expertise, so we defer to you there.

# %%
dev_tag = 'BLUETOOTH01'
sub_stats = Ex_stats[['Device','Avg HR','RMSSD','PC Removed','Breath Count','Avg IE ratio','Seq Var','Avg QoM']]
sub_stats.to_csv('./outfiles/'+sess_tag+'_summary.csv')
